# %%
# Python Image Library
import PIL.Image
import PIL.ImageDraw

# use face detection model in Dlib throug face_recognition library
import face_recognition

# %%
# Load the jpg file into a numpy array
image = face_recognition.load_image_file('people.jpg')
image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[199, 216, 223],
#         [200, 217, 224],
#         [200, 217, 224],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[199, 216, 223],
#         [200, 217, 224],
#         [201, 218, 225],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[199, 216, 223],
#         [201, 218, 225],
#         [202, 219, 226],
# ...

# %%
# Find all the faces in the image using pre-trained HOG face detector
face_locations = face_recognition.face_locations(image)
# returns top, right, bottom, left co-ordinates of face if face found
print(face_locations)
# Out:
# [(163, 605, 271, 497), (186, 364, 275, 275), (211, 175, 319, 67), (295, 760, 402, 653), (271, 474, 378, 366), (152, 832, 259, 724)]

# %%
# Number of faces in the image
number_of_faces = len(face_locations)
print(f'I found {number_of_faces} face(s) in this photograph.')
# Out:
# I found 6 face(s) in this photograph.

# %%
# Load the image into a Python Image Library object so that we can draw on top of it and display it
pil_image = PIL.Image.fromarray(image)
pil_image
# Out:
# <PIL.Image.Image image mode=RGB size=1000x667 at 0x7FA4A75BDF60>

# %%
for face_location in face_locations:
    # Print the location of each face in this image. Each face is a list of co-ordinates in (top, right, bottom, left) order.
    top, right, bottom, left = face_location
    print(f'A face is located at pixel location Top: {top}, Left: {left}, Bottom: {bottom}, Right: {right}.')
    
    # Let's draw a box around the face
    draw = PIL.ImageDraw.Draw(pil_image) # draw object of PIL
    draw.rectangle([left,top,right,bottom],outline='red', width=4)
# Out:
# A face is located at pixel location Top: 163, Left: 497, Bottom: 271, Right: 605.
# A face is located at pixel location Top: 186, Left: 275, Bottom: 275, Right: 364.
# A face is located at pixel location Top: 211, Left: 67, Bottom: 319, Right: 175.
# A face is located at pixel location Top: 295, Left: 653, Bottom: 402, Right: 760.
# A face is located at pixel location Top: 271, Left: 366, Bottom: 378, Right: 474.
# A face is located at pixel location Top: 152, Left: 724, Bottom: 259, Right: 832.

# %%
pil_image
# Out:
# <PIL.Image.Image image mode=RGB size=1000x667 at 0x7FA4A75BDF60>
